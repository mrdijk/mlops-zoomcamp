# %%
import pandas as pd
import numpy as np

# %%
taxi_januari = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')
taxi_februari = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet')

# %%
taxi_januari.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
duration = (taxi_januari['tpep_dropoff_datetime'] - taxi_januari['tpep_pickup_datetime'])
standard_dev_trips = np.std(duration)
standard_dev_trips
# Out:
# 2555

# %%
duration_no_outliers = [x for x in duration if x.seconds > 60 and x.seconds < 3600]
duration_no_outliers
# Out:
# [Timedelta('0 days 00:08:26'),
#  Timedelta('0 days 00:06:19'),
#  Timedelta('0 days 00:12:45'),
#  Timedelta('0 days 00:09:37'),
#  Timedelta('0 days 00:10:50'),
#  Timedelta('0 days 00:12:18'),
#  Timedelta('0 days 00:10:27'),
#  Timedelta('0 days 00:22:44'),
#  Timedelta('0 days 00:14:56'),
#  Timedelta('0 days 00:10:54'),
#  Timedelta('0 days 00:08:44'),
#  Timedelta('0 days 00:33:41'),
#  Timedelta('0 days 00:29:41'),
#  Timedelta('0 days 00:19:54'),
#  Timedelta('0 days 00:15:22'),
#  Timedelta('0 days 00:09:06'),
#  Timedelta('0 days 00:22:28'),
#  Timedelta('0 days 00:14:49'),
#  Timedelta('0 days 00:06:00'),
#  Timedelta('0 days 00:14:18'),
#  Timedelta('0 days 00:06:33'),
#  Timedelta('0 days 00:30:30'),
#  Timedelta('0 days 00:07:26'),
#  Timedelta('0 days 00:10:12'),
#  Timedelta('0 days 00:19:15'),
#  Timedelta('0 days 00:19:29'),
#  Timedelta('0 days 00:17:14'),
#  Timedelta('0 days 00:12:47'),
#  Timedelta('0 days 00:02:50'),
#  Timedelta('0 days 00:05:31'),
# ...

# %%
(len(duration_no_outliers)/len(duration))*100
# Out:
# 98.11156116899691
